# %%
import mysql.connector
import pandas as pd
import os
cnx = mysql.connector.connect(user='fgonzalez', password='6bM59%1**t^O',
                              host='192.168.0.254',
                              database='encuesta',
                              use_pure=False)
                              
cursor=cnx.cursor(buffered=True)

# %%
carreras=pd.read_sql('select * from carreras',cnx)
# Out:
# c:\Users\fgonzalez\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(

# %%
carreras
# Out:
#       id  clave_carrera  clave_plantel                   carrera  \
# 0      1            105              1         Diseño Industrial
# 1      2            123              1                 Urbanismo
# 2      3            401              2            Artes Visuales
# 3      4            405              2      Comunicación Gráfica
# 4      5            406              2            Diseño Gráfico
# ..   ...            ...            ...                       ...
# 218  219            226           1000             Neurociencias
# 219  220            228           1000        Órtesis y Prótesis
# 220  221            321           1000  Negocios Internacionales
# 221  222            102              1              Arquitectura
# 222  223            103              1  Arquitectura del paisaje
#
#                         plantel  area
# 0      Facultad de Arquitectura     1
# 1      Facultad de Arquitectura     1
# 2    Facultad de Artes y Diseño     4
# ...

# %%
for i in range(len(carreras)):
    print("array('"+carreras['carrera'].values[i]+"','"+carreras['plantel'].values[i]+"'),")
# Out:
# array('Diseño Industrial','Facultad de Arquitectura'),
# array('Urbanismo','Facultad de Arquitectura'),
# array('Artes Visuales','Facultad de Artes y Diseño'),
# array('Comunicación Gráfica','Facultad de Artes y Diseño'),
# array('Diseño Gráfico','Facultad de Artes y Diseño'),
# array('Diseño y Comunicación Visual','Facultad de Artes y Diseño'),
# array('Arte y Diseño','Facultad de Artes y Diseño'),
# array('Cinematografía','Facultad de Artes y Diseño'),
# array('Técnico','Facultad de Artes y Diseño'),
# array('Actuaría','Facultad de Ciencias'),
# array('Ciencias de la Computación','Facultad de Ciencias'),
# array('Física','Facultad de Ciencias'),
# array('Matemáticas','Facultad de Ciencias'),
# array('Ciencias de la Tierra','Facultad de Ciencias'),
# array('Física Biomédica','Facultad de Ciencias'),
# array('Matemáticas Aplicadas','Facultad de Ciencias'),
# array('Biología','Facultad de Ciencias'),
# array('Manejo Sustentable de Zonas Costeras','Facultad de Ciencias'),
# ...

# %%
2105/6464
# Out:
# 0.3256497524752475
